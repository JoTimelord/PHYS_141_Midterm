# %% [markdown]
# <a href="https://colab.research.google.com/github/JoTimelord/PHYS_141_Midterm/blob/Joy/CORE_MASS_TRAJECTORY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_fwf("corrmass.dat.R", header=None)
print(data)
# Out:
#            0        1        2         3
# 0    100.000  0.00000 -100.000  -0.00000
# 1     99.998  0.59949  -99.998  -0.59949
# 2     99.991  1.19900  -99.991  -1.19900
# 3     99.980  1.79840  -99.980  -1.79840
# 4     99.964  2.39770  -99.964  -2.39770
# ..       ...      ...      ...       ...
# 696   99.337 -1.02800  -99.337  10.28000
# 697   99.412 -9.68410  -99.412   9.68410
# 698   99.483 -9.08790  -99.483   9.08790
# 699   99.548 -8.49130  -99.548   8.49130
# 700   99.610 -7.89440  -99.610   7.89440
#
# [701 rows x 4 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d4903983-3ec2-46e0-bfba-7d7f86e921a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4903983-3ec2-46e0-bfba-7d7f86e921a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving corrmass.dat.R to corrmass.dat.R

# %%
pwd
# Out:
# '/content'

# %%
import matplotlib.pyplot as plt
plt.plot(-data[2],-data[3])
plt.xlim([-500,500])
plt.ylim([-500,500])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.xlim([-100,100])
plt.ylim([-100,100])
plt.plot(-data[2],-data[3])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
plt.xlim([-200,200])
plt.ylim([-200,200])
plt.plot(data[0], data[1], color='r', label='1')
plt.plot(data[2], data[3], color='g', label='2')
plt.show()
