# %% [markdown]
# <a href="https://colab.research.google.com/github/JoTimelord/PHYS_141_Midterm/blob/main/Final_CORE_MASS_TRAJECTORY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_fwf("cm.data.R", header=None)
print(data)
# Out:
#            0        1       2         3
# 0    82.0000  0.00000 -82.000  -0.00000
# 1    81.9970  0.59949 -81.997  -0.59949
# 2    81.9870  1.19890 -81.987  -1.19890
# 3    81.9700  1.79830 -81.970  -1.79830
# 4    81.9470  2.39750 -81.947  -2.39750
# ..       ...      ...     ...       ...
# 696  -3.1349 -2.94680  31.349  29.46800
# 697  -3.0715 -3.04390  30.715  30.43900
# 698  -3.0063 -3.13940  30.063  31.39400
# 699  -2.9395 -3.23320  29.395  32.33200
# 700  -2.8712 -3.32520  28.712  33.25200
#
# [701 rows x 4 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd751eef-defa-4256-b4c7-29e8222d3a68" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd751eef-defa-4256-b4c7-29e8222d3a68">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cm.data.R to cm.data.R

# %%
import matplotlib.pyplot as plt
plt.plot(-data[2],-data[3])
plt.xlim([-100,100])
plt.ylim([-100,100])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.xlim([-100,100])
plt.ylim([-100,100])
plt.plot(data[2],data[3])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
plt.xlim([-110,110])
plt.ylim([-110,110])
plt.plot(-data[2], -data[3], color='r', label='1')
plt.plot(data[2], data[3], color='g', label='2')
plt.show()
